# %%
# %matplotlib inline
import os

from plot_db import plot_db
DATABASE_DIR = '/Users/ajaver/OneDrive - Imperial College London/compare_strains_DB'

tab_name = 'medians_split'
filt_path_range = 0
filt_frac_good = 0

database_name = 'control_experiments_short_movies_new.db'
db_path = os.path.join(DATABASE_DIR, database_name)
db_data = plot_db(db_path, filt_path_range, filt_frac_good, tab_name)

#filter, double_pick_260117 has problems with the labelling
#db_data.experiments = db_data.experiments[db_data.experiments['exp_name']=='double_pick_200117']
#db_data.feats = db_data.feats[db_data.feats['exp_name']=='double_pick_200117']
print(db_data.feats['exp_name'].unique())
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:901: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# ['double_pick_260117' 'double_pick_200117']

# %%
db_data.plot(['length',  'Strain', 'Picker'])
db_data.plot(['midbody_speed_pos',  'Strain'])
db_data.plot(['midbody_speed_pos',  'Strain', 'Picker'])
db_data.plot(['midbody_speed_pos', 'Strain', 'N_Worms'])
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:926: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
database_name = 'control_experiments_demo.db'
db_path = os.path.join(DATABASE_DIR, database_name)
db_demo = plot_db(db_path, filt_path_range, filt_frac_good, tab_name)

#filter, double_pick_260117 has problems with the labelling
#db_data.experiments = db_data.experiments[db_data.experiments['exp_name']=='double_pick_200117']
#db_data.feats = db_data.feats[db_data.feats['exp_name']=='double_pick_200117']
print(db_demo.feats['exp_name'].unique())

db_demo.plot(['length',  'Strain', 'Picker'])
db_demo.plot(['midbody_speed_pos',  'Strain'])
db_demo.plot(['midbody_speed_pos',  'Strain', 'Picker'])
db_demo.plot(['midbody_speed_pos', 'Strain', 'N_Worms'])
# Out:
# ['double_pick_200117' 'double_pick_260117']
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:926: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
